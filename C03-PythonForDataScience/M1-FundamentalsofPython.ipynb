# %% [markdown]
# ### Important Libraries for Data Science
# - NumPy: For numerical operations and array manipulation.
# - Pandas: For data manipulation and analysis.
# - Scikit-learn: For machine learning algorithms and tools.
# - TensorFlow: For building and deploying machine learning models.
# - PyTorch: Another popular library for deep learning.
# - Matplotlib: For creating visualizations and plots.
# - Seaborn: For statistical data visualization.
#
# Learning is a Journey and challenges are part of it, so approach it with curiocity.

# %% [markdown]
# ### Computational thinking can be broken down into the following stages
# 1. **Decomposition** or breaking down a complex problem into smaller tasks
#
# 2. **Pattern recognition** or spotting trends that can aid us in solving our problems
#
# 3. **Abstraction** or filtering out unnecessary details to focus on key information
#
# 4. **Algorithm** development or creating a step-by-step procedure to solve a problem

# %% [markdown]
# ### Software Development Life Cycle
# - Planning **|** Identification of the application’s purpose and features offered **|** To track workouts and nutrition
# - Requirement Analysis **|** Identification of the requirements for developing the application **|** To track activity logging and calories and to build user profiles
# - Design **|** Identification of the technology stack and design of the user interface **|** Application on mobile app stores; clean, mobile-friendly UI
# - Implementation **|** Implementation of the features as code **|** Features such as GPS tracking and nutrition logging
# - Testing **|** Testing for bugs and security issues and to check if the application works as intended **|** Testing by developers and testers
# - Deployment **|** Making the application available for mass usage **|** Make the application available on app stores such as the Google Play Store and the Apple App Store
# - Maintenance **|** Fixing bugs, releasing updates and improving the app based on user feedback **|** Responding to user feedback and rolling out regular updates

# %% [markdown]
# ### Code Management
# - Compiler
# - Interpreters (python uses interpreter)
# - Version control system
# - Package Managers: PIP
# - Build Tools: setup tools, poetry
# - Frameworks: Flask (simple application), Django (Large application)
# - Libraries: numpy, pandas, Matplotlib, seaborn, TensorFlow, PyTorch

# %% [markdown]
# ### Variables and Data Types

# %% [markdown]
# #### Fundamental Data Types
# - Integers
# - Floats
# - Strings
# - Booleans
# - NoneType

# %%
# String is a Data type which is often used to store textual data 
empty_str = ''
empty_str
# Out:
# ''

# %%
type(empty_str)
# Out:
# str

# %%
character = 'h'
character
# Out:
# 'h'

# %%
type(character)
# Out:
# str

# %%
word = 'Hello'
word
# Out:
# 'Hello'

# %%
type(word)
# Out:
# str

# %%
sentence = 'Hello World!'
sentence
# Out:
# 'Hello World!'

# %%
type(sentence)
# Out:
# str

# %%
name = input('What is your name? ')
age = input('How old are you? ')

# %%
print('Hello', name, '!')
# Out:
# Hello Tanvir !

# %%
print('Hello', name + '!')
# Out:
# Hello Tanvir!

# %%
age_after_six_years = int(age) + 6

# %%
print(age_after_six_years)
# Out:
# 38

# %%
print(type(age))
print(type(age_after_six_years))
# Out:
# <class 'str'>
# <class 'int'>

# %%
print('Hello', name + '! After six years, you will be', str(age_after_six_years) + '!')
# Out:
# Hello Tanvir! After six years, you will be 38!

# %% [markdown]
# #### Important Links
# https://learn.microsoft.com/en-us/azure/architecture/data-science-process/overview
