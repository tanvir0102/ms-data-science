# %%
import numpy as np

# Creating a numpy array
arr = np.array([1, 2, 3, 4, 5, 6])

# Initial shape of the array
print("Initial shape:", arr.shape)

# Changing the shape of the array
arr.shape = (2, 3)

# Array after reshaping
print("New shape:", arr.shape)
print("Reshaped array:\n", arr)
# Out:
# Initial shape: (6,)
# New shape: (2, 3)
# Reshaped array:
#  [[1 2 3]
#  [4 5 6]]

# %%
import pandas as pd

# %%
df = pd.read_csv('tourist_spots.csv')

# Get the number of unique states
unique_states = df['State'].nunique()

print("There are", unique_states, "unique states in the dataset.")
# Out:
# There are 33 unique states in the dataset.

# %%
df.columns
# Out:
# Index(['Zone', 'State', 'City', 'Name', 'Type', 'Establishment Year',
#        'time needed to visit in hrs', 'Google review rating',
#        'Entrance Fee in INR', 'Airport with 50km Radius', 'Significance',
#        'DSLR Allowed', 'Number of google review in lakhs',
#        'Best Time to visit'],
#       dtype='object')

# %%
filtered_df = df[(df['Google review rating'] >= 4.5) & (df['Zone'] == 'Northern')]

# %%
df = pd.read_csv('tourist_spots.csv')

# Filter the dataframe for spots of botanical significance
botanical_spots = df[df['Significance'].str.contains('botanical', case=False, na=False)]

# Calculate the mean number of Google reviews in lakhs for these spots, rounding to two decimal places
mean_reviews = round(botanical_spots['Number of google review in lakhs'].mean(), 2)

print("The mean number of Google reviews in lakhs for botanical spots is:", mean_reviews)
# Out:
# The mean number of Google reviews in lakhs for botanical spots is: 0.29

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('tourist_spots.csv')

# %%
# You may need to modify the column names according to your dataset
median_reviews = df.groupby(['Zone', 'DSLR Allowed'])['Number of google review in lakhs'].median().reset_index()

# %%
plt.figure(figsize=(10, 6))
barplot = sns.barplot(x='Zone', y='Number of google review in lakhs', hue='DSLR Allowed', data=median_reviews, ci=None)
plt.title('Median Google Review Ratings in Lakhs by Zone and DSLR Policy')
plt.xlabel('Zone')
plt.ylabel('Median Number of Google Reviews in Lakhs')
plt.show()
# Out:
# C:\Users\mohammad_tanvir\AppData\Local\Temp\ipykernel_26192\1724614986.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   barplot = sns.barplot(x='Zone', y='Number of google review in lakhs', hue='DSLR Allowed', data=median_reviews, ci=None)

# %%
import pandas as pd

# %%
df = pd.read_csv('tourist_spots.csv')

# %%
specific_entry = df[df['time needed to visit in hrs'] == 7]

# %%
if not specific_entry.empty:
    entry_type = specific_entry['Type'].iloc[0]
    print(f"The 'Type' of the entry with seven hours needed to visit is: {entry_type}")
else:
    print("No entries found with the specified time duration.")
# Out:
# The 'Type' of the entry with seven hours needed to visit is: Science

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('tourist_spots.csv')

# %%
numeric_df = df.select_dtypes(include=['int64', 'float64'])

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(numeric_df.corr(), annot=True, fmt=".2f", cmap="coolwarm")
plt.title('Heatmap of Numeric Columns')
plt.show()

# %%
import pandas as pd

# %%
df = pd.read_csv('tourist_spots.csv')

# %%
filtered_spots = df[df['Type'].isin(['Amusement Park', 'Vineyard'])]

# %%
total_budget = filtered_spots['Entrance Fee in INR'].sum()

# %%
print("Total budget needed for entrance fees to all amusement parks and vineyards:", total_budget, "INR")
# Out:
# Total budget needed for entrance fees to all amusement parks and vineyards: 4238 INR

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('nykaa.csv')
df.columns
# Out:
# Index(['Product Id', 'Product Brand Code', 'Product Category', 'Product Brand',
#        'Product Name', 'Product Price', 'Product Url', 'Product Description',
#        'Product Image Url', 'Product Tags', 'Product Contents',
#        'Product Rating', 'Product Reviews Count', 'Expected Category Count',
#        'Expected Brand Count'],
#       dtype='object')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('nykaa.csv')

# %%
df_filtered = df[df['Product Brand'].isin(['Biotique', 'Himalaya', 'Lotus Herbals'])]

# %%
plt.figure(figsize=(10, 6))
ax = sns.countplot(x='Product Brand', data=df_filtered, order=['Biotique', 'Himalaya', 'Lotus Herbals'])
plt.title('Count of Products by Brand')
plt.xlabel('Brand')
plt.ylabel('Number of Products')
plt.show()

# %%
product_counts = df_filtered['Product Brand'].value_counts()
print(product_counts)
# Out:
# Product Brand
# Biotique         10
# Lotus Herbals     8
# Himalaya          8
# Name: count, dtype: int64
